# %%
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data_root = "https://github.com/ageron/data/raw/main/"
lifesat = pd.read_csv(data_root + "lifesat/lifesat.csv")

# %%
lifesat.to_csv("lifesat.csv", index=False)

# %%
X = lifesat[["GDP per capita (USD)"]].values
y = lifesat[["Life satisfaction"]].values

# %%
lifesat.plot(kind='scatter', grid=True,
             x="GDP per capita (USD)", y="Life satisfaction")
plt.axis([23_500, 62_500, 4, 9])
# Out:
# (np.float64(23500.0), np.float64(62500.0), np.float64(4.0), np.float64(9.0))

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
X_new = [[37655.2]]
model.predict(X_new)
# Out:
# array([[6.30165767]])

# %%
model.coef_
# Out:
# array([[6.77889969e-05]])

# %%
model.intercept_
# Out:
# array([3.74904943])

# %%
lifesat.plot(kind='scatter', grid=True,
             x="GDP per capita (USD)", y="Life satisfaction")
plt.axis([23_500, 62_500, 4, 9])

coeff = model.coef_
intercept = model.intercept_
linex = [i for i in range(25000, 65000, 5000)]
liney = [(intercept + (i * coeff[0])) for i in linex]

plt.plot(linex, liney, color='r')
