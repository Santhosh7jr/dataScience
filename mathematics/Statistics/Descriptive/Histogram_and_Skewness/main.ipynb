# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
array = np.array([11, 12, 14, 18, 20, 22, 24, 26, 30, 31, 35, 36, 37, 40, 41, 42, 43, 50])

sns.histplot(array, bins=10, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.boxplot(array, )
# Out:
# <Axes: >

# %%
array = np.array([1, 6, 7, 11, 12, 13, 16, 17, 18, 19, 21, 21, 22, 23, 24, 26, 26, 27, 27, 28, 29, 31, 31, 32, 32, 33, 33, 34, 36, 36, 36, 37, 37, 38, 38, 39, 42, 48])
sns.histplot(array, bins=10, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
#
