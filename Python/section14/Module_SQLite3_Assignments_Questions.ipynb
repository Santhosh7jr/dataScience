# %%
import sqlite3

# %% [markdown]
# # Module: SQLite3 Assignments
# ## Lesson: SQLite3
# ### Assignment 1: Creating and Connecting to a Database
#
# 1. Write a Python function to create a new SQLite3 database named `test.db`.
# 2. Write a Python function to create a table named `employees` with columns `id` (integer), `name` (text), `age` (integer), and `department` (text) in the `test.db` database.

# %%
connection = sqlite3.connect("test.db")
cursor = connection.cursor()

def table():
    cursor.execute('create table if not exists employees(id int, name text, age int, department text)')
    connection.commit()

table()

# %% [markdown]
# ### Assignment 2: Inserting Data
#
# 1. Write a Python function to insert a new employee into the `employees` table.
# 2. Insert at least 5 different employees into the `employees` table.

# %%
def insert(data):
    cursor.executemany('insert into employees values(?, ?, ?, ?);', data)
    connection.commit()

employee_data = [
    (1, 'guru', 40, 'HR'),
    (2, 'giri', 42, 'tech'),
    (3, 'mari', 45, 'consultant'),
    (4, 'kuri', 30, 'manager'),
    (5, 'chari', 21, 'testing'),
]

insert(employee_data)

# %% [markdown]
# ### Assignment 3: Querying Data
#
# 1. Write a Python function to fetch and display all records from the `employees` table.
# 2. Write a Python function to fetch and display all employees from a specific department.

# %%
def display():
    cursor.execute('select * from employees;')
    
    for row in cursor.fetchall():
        print(row)

def specific_dept_employees(dept):

    cursor.execute('select * from employees where department = ?', (dept, ))

    for row in cursor.fetchall():
        print(row)

display()
print()
specific_dept_employees("tech")
# Out:
# (1, 'guru', 23, 'HR')
# (3, 'mari', 45, 'tech')
# (4, 'kuri', 30, 'manager')
# (5, 'chari', 21, 'testing')
# (1, 'guru', 23, 'HR')
# (3, 'mari', 45, 'tech')
# (4, 'kuri', 30, 'manager')
# (5, 'chari', 21, 'testing')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (14, 'zaid', 30, 'hacker')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (14, 'zaid', 30, 'hacker')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (14, 'zaid', 30, 'hacker')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (14, 'zaid', 30, 'hacker')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (14, 'zaid', 30, 'hacker')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# ...

# %% [markdown]
# ### Assignment 4: Updating Data
#
# 1. Write a Python function to update the department of an employee based on their `id`.
# 2. Update the department of at least 2 employees and display the updated records.

# %%
def update_dept(id, dept):

    cursor.execute('update employees set department = ? where id = ?', (dept, id))
    connection.commit()

update_dept(2, "HR")
update_dept(3, "tech")

display()
# Out:
# (1, 'guru', 23, 'HR')
# (3, 'mari', 45, 'tech')
# (4, 'kuri', 30, 'manager')
# (5, 'chari', 21, 'testing')
# (1, 'guru', 23, 'HR')
# (3, 'mari', 45, 'tech')
# (4, 'kuri', 30, 'manager')
# (5, 'chari', 21, 'testing')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (14, 'zaid', 30, 'hacker')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (14, 'zaid', 30, 'hacker')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (14, 'zaid', 30, 'hacker')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (14, 'zaid', 30, 'hacker')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (14, 'zaid', 30, 'hacker')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# ...

# %% [markdown]
# ### Assignment 5: Deleting Data
#
# 1. Write a Python function to delete an employee from the `employees` table based on their `id`.
# 2. Delete at least 1 employee and display the remaining records.

# %%
def delete_employee(id):

    cursor.execute('delete from employees where id = ?', (id, ))
    connection.commit()

delete_employee(2)
display()
# Out:
# (1, 'guru', 23, 'HR')
# (3, 'mari', 45, 'tech')
# (4, 'kuri', 30, 'manager')
# (5, 'chari', 21, 'testing')
# (1, 'guru', 23, 'HR')
# (3, 'mari', 45, 'tech')
# (4, 'kuri', 30, 'manager')
# (5, 'chari', 21, 'testing')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (14, 'zaid', 30, 'hacker')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (14, 'zaid', 30, 'hacker')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (14, 'zaid', 30, 'hacker')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (14, 'zaid', 30, 'hacker')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (14, 'zaid', 30, 'hacker')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# ...

# %% [markdown]
# ### Assignment 6: Advanced Queries
#
# 1. Write a Python function to fetch and display employees older than a certain age.
# 2. Write a Python function to fetch and display employees whose names start with a specific letter.

# %%
def select_employees_based_on_age(age):

    cursor.execute('select * from employees where age >= ?', (age, ))

    for employee in cursor.fetchall():
        print(employee)

def select_specific_employee_by_name(starting_name):

    cursor.execute('select * from employees where name like ?', (starting_name + "%", ))

    for employee in cursor.fetchall():
        print(employee)

select_employees_based_on_age(40)
print()
select_specific_employee_by_name('gu')
# Out:
# (3, 'mari', 45, 'tech')
# (3, 'mari', 45, 'tech')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (10, 'ironMan', 50, 'movies')
# (11, 'sherlock Holmes', 70, 'detective')
# (12, 'vote chor', 80, 'politics')
# (1, 'guru', 40, 'HR')
# (3, 'mari', 45, 'tech')
#
# (1, 'guru', 23, 'HR')
# (1, 'guru', 23, 'HR')
# (1, 'guru', 40, 'HR')

# %% [markdown]
# ### Assignment 7: Handling Transactions
#
# 1. Write a Python function to insert multiple employees into the `employees` table in a single transaction. Ensure that if any insertion fails, none of the insertions are committed.
# 2. Write a Python function to update the age of multiple employees in a single transaction. Ensure that if any update fails, none of the updates are committed.

# %%
def insert_data_of_multiple_employees(data):

    connection.execute("begin")

    try:
        cursor.executemany('insert into employees values(?, ?, ?, ?)', data)
        connection.commit()

    except Exception as e:
        connection.rollback()
        print(e)

def update_age_of_multiple_employees(age_data):

    connection.execute("begin")

    try:
        cursor.executemany('update employees set age = ? where name = ?', age_data)
        connection.commit()

    except Exception as e:
        connection.rollback()
        print(e)

employee_data = [
    (10, "ironMan", 50, "movies"),
    (11, "sherlock Holmes", 70, "detective"),
    (12, "vote chor", 80, "politics"),
    (14, "zaid", 30, "hacker"),
]

age_data = [
    (23, "guru"),
    (32, "giri")
]

insert_data_of_multiple_employees(employee_data)
update_age_of_multiple_employees(age_data)
