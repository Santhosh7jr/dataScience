# %%
import matplotlib.pyplot as plt

# %%
data = {
    "height" : [74, 80, 75, 60, 82, 72, 79, 72, 68, 81, 67, 73, 71, 70, 83, 75, 77],
    "weight" : [170, 180, 175, 160, 178, 169, 185, 165, 170, 172, 164, 180, 162, 175, 173, 169, 186]
}

plt.scatter(data["height"], data["weight"])
